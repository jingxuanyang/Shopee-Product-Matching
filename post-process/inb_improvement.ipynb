# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
RESULTS_PATH = '../input/shopee-competition-results/'
test_result_dict = joblib.load(RESULTS_PATH+'test_result_dict.pkl')
image_ensemble_df = pd.read_csv(RESULTS_PATH+'image_ensemble_df.csv')

test_tfidf_result_df = pd.read_csv(RESULTS_PATH+'test_tfidf_result_df.csv')
test_bert_result_dict = joblib.load(RESULTS_PATH+'test_bert_result_dict.pkl')
text_ensemble_df = pd.read_csv(RESULTS_PATH+'text_ensemble_df.csv')

tfidf_resnet_union_df = pd.read_csv(RESULTS_PATH+'tfidf_resnet_union_df.csv')
nfnet_sbert_union_df = pd.read_csv(RESULTS_PATH+'nfnet_sbert_union_df.csv')
tfidf_resnet_ensemble_df = pd.read_csv(RESULTS_PATH+'tfidf_resnet_ensemble_df.csv')
nfnet_sbert_ensemble_df = pd.read_csv(RESULTS_PATH+'nfnet_sbert_ensemble_df.csv')
text_image_union_df = pd.read_csv(RESULTS_PATH+'text_image_union_df.csv')

# %%
inb_results = [[0 for i in range(6)] for j in range(10)]

inb_results[0][0] = round(test_result_dict['resnet50_f1']['arcface_min2'].max(),6)
inb_results[0][1] = round(test_result_dict['resnet50_recall']['arcface_min2'].max(),6)
inb_results[0][2] = round(test_result_dict['resnet50_precision']['arcface_min2'].max(),6)
inb_results[0][3] = round(test_result_dict['resnet50_f1']['arcface_inb'].max(),6)
inb_results[0][4] = round(test_result_dict['resnet50_recall']['arcface_inb'].max(),6)
inb_results[0][5] = round(test_result_dict['resnet50_precision']['arcface_inb'].max(),6)

inb_results[1][0] = round(test_result_dict['resnext50_32x4d_f1']['arcface_min2'].max(),6)
inb_results[1][1] = round(test_result_dict['resnext50_32x4d_recall']['arcface_min2'].max(),6)
inb_results[1][2] = round(test_result_dict['resnext50_32x4d_precision']['arcface_min2'].max(),6)
inb_results[1][3] = round(test_result_dict['resnext50_32x4d_f1']['arcface_inb'].max(),6)
inb_results[1][4] = round(test_result_dict['resnext50_32x4d_recall']['arcface_inb'].max(),6)
inb_results[1][5] = round(test_result_dict['resnext50_32x4d_precision']['arcface_inb'].max(),6)

inb_results[2][0] = round(test_result_dict['densenet121_f1']['arcface_min2'].max(),6)
inb_results[2][1] = round(test_result_dict['densenet121_recall']['arcface_min2'].max(),6)
inb_results[2][2] = round(test_result_dict['densenet121_precision']['arcface_min2'].max(),6)
inb_results[2][3] = round(test_result_dict['densenet121_f1']['arcface_inb'].max(),6)
inb_results[2][4] = round(test_result_dict['densenet121_recall']['arcface_inb'].max(),6)
inb_results[2][5] = round(test_result_dict['densenet121_precision']['arcface_inb'].max(),6)

inb_results[3][0] = round(test_result_dict['efficientnet_b3_f1']['arcface_min2'].max(),6)
inb_results[3][1] = round(test_result_dict['efficientnet_b3_recall']['arcface_min2'].max(),6)
inb_results[3][2] = round(test_result_dict['efficientnet_b3_precision']['arcface_min2'].max(),6)
inb_results[3][3] = round(test_result_dict['efficientnet_b3_f1']['arcface_inb'].max(),6)
inb_results[3][4] = round(test_result_dict['efficientnet_b3_recall']['arcface_inb'].max(),6)
inb_results[3][5] = round(test_result_dict['efficientnet_b3_precision']['arcface_inb'].max(),6)

inb_results[4][0] = round(test_result_dict['eca_nfnet_l0_f1']['arcface_min2'].max(),6)
inb_results[4][1] = round(test_result_dict['eca_nfnet_l0_recall']['arcface_min2'].max(),6)
inb_results[4][2] = round(test_result_dict['eca_nfnet_l0_precision']['arcface_min2'].max(),6)
inb_results[4][3] = round(test_result_dict['eca_nfnet_l0_f1']['arcface_inb'].max(),6)
inb_results[4][4] = round(test_result_dict['eca_nfnet_l0_recall']['arcface_inb'].max(),6)
inb_results[4][5] = round(test_result_dict['eca_nfnet_l0_precision']['arcface_inb'].max(),6)

inb_results[5][0] = round(test_bert_result_dict['bert-base-multilingual-uncased_f1']['arcface_min2'].max(),6)
inb_results[5][1] = round(test_bert_result_dict['bert-base-multilingual-uncased_recall']['arcface_min2'].max(),6)
inb_results[5][2] = round(test_bert_result_dict['bert-base-multilingual-uncased_precision']['arcface_min2'].max(),6)
inb_results[5][3] = round(test_bert_result_dict['bert-base-multilingual-uncased_f1']['arcface_inb'].max(),6)
inb_results[5][4] = round(test_bert_result_dict['bert-base-multilingual-uncased_recall']['arcface_inb'].max(),6)
inb_results[5][5] = round(test_bert_result_dict['bert-base-multilingual-uncased_precision']['arcface_inb'].max(),6)

inb_results[6][0] = round(test_bert_result_dict['bert-base-indonesian-1.5G_f1']['arcface_min2'].max(),6)
inb_results[6][1] = round(test_bert_result_dict['bert-base-indonesian-1.5G_recall']['arcface_min2'].max(),6)
inb_results[6][2] = round(test_bert_result_dict['bert-base-indonesian-1.5G_precision']['arcface_min2'].max(),6)
inb_results[6][3] = round(test_bert_result_dict['bert-base-indonesian-1.5G_f1']['arcface_inb'].max(),6)
inb_results[6][4] = round(test_bert_result_dict['bert-base-indonesian-1.5G_recall']['arcface_inb'].max(),6)
inb_results[6][5] = round(test_bert_result_dict['bert-base-indonesian-1.5G_precision']['arcface_inb'].max(),6)

inb_results[7][0] = round(test_bert_result_dict['distilbert-base-indonesian_f1']['arcface_min2'].max(),6)
inb_results[7][1] = round(test_bert_result_dict['distilbert-base-indonesian_recall']['arcface_min2'].max(),6)
inb_results[7][2] = round(test_bert_result_dict['distilbert-base-indonesian_precision']['arcface_min2'].max(),6)
inb_results[7][3] = round(test_bert_result_dict['distilbert-base-indonesian_f1']['arcface_inb'].max(),6)
inb_results[7][4] = round(test_bert_result_dict['distilbert-base-indonesian_recall']['arcface_inb'].max(),6)
inb_results[7][5] = round(test_bert_result_dict['distilbert-base-indonesian_precision']['arcface_inb'].max(),6)

inb_results[8][0] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_f1']['arcface_min2'].max(),6)
inb_results[8][1] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_recall']['arcface_min2'].max(),6)
inb_results[8][2] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_precision']['arcface_min2'].max(),6)
inb_results[8][3] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_f1']['arcface_inb'].max(),6)
inb_results[8][4] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_recall']['arcface_inb'].max(),6)
inb_results[8][5] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_precision']['arcface_inb'].max(),6)

inb_results[9][0] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_f1']['arcface_min2'].max(),6)
inb_results[9][1] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_recall']['arcface_min2'].max(),6)
inb_results[9][2] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_precision']['arcface_min2'].max(),6)
inb_results[9][3] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_f1']['arcface_inb'].max(),6)
inb_results[9][4] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_recall']['arcface_inb'].max(),6)
inb_results[9][5] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_precision']['arcface_inb'].max(),6)

# %%
inb_results_df = pd.DataFrame(inb_results,columns=['f1_min2','recall_min2','precision_min2','f1_inb','recall_inb','precision_inb'],index=['resnet50','resnext50_32x4d','densenet121','efficientnet_b3','eca_nfnet_l0','bert-base-multilingual-uncased','bert-base-indonesian-1.5G','distilbert-base-indonesian','paraphrase-xlm-r-multilingual-v1','paraphrase-distilroberta-base-v1'])
inb_results_df
# Out:
#                                    f1_min2  recall_min2  precision_min2  \
# resnet50                          0.762153     0.737980        0.908140
# resnext50_32x4d                   0.768830     0.750740        0.905592
# densenet121                       0.766886     0.752253        0.917053
# efficientnet_b3                   0.780399     0.777227        0.895831
# eca_nfnet_l0                      0.798483     0.794252        0.888775
# bert-base-multilingual-uncased    0.825374     0.856103        0.871410
# bert-base-indonesian-1.5G         0.820426     0.856187        0.853064
# distilbert-base-indonesian        0.813436     0.854869        0.854233
# paraphrase-xlm-r-multilingual-v1  0.829395     0.862709        0.873610
# paraphrase-distilroberta-base-v1  0.808062     0.845159        0.860479
#
#                                     f1_inb  recall_inb  precision_inb
# resnet50                          0.766813    0.735445       0.927010
# ...

# %%
inb_results_df.to_csv('inb_results_df.csv')

# %%
inb_results_f1_df = inb_results_df.iloc[:, [0,3]]
ax = inb_results_f1_df.plot(marker='o',ylabel='score',rot=70,figsize=(12,6))
ax.set_xticks(range(len(inb_results_f1_df.index)))
ax.set_xticklabels(inb_results_f1_df.index)
# plt.legend(loc='center left')
fig = ax.get_figure()
fig.savefig('../doc/figures/inb_results_f1_df.pdf',pad_inches=0,bbox_inches='tight')

# %%
inb_results_recall_df = inb_results_df.iloc[:, [1,4]]
ax = inb_results_recall_df.plot(marker='o',ylabel='score',rot=70,figsize=(12,6))
ax.set_xticks(range(len(inb_results_recall_df.index)))
ax.set_xticklabels(inb_results_recall_df.index)
# plt.legend(loc='center left')
fig = ax.get_figure()
fig.savefig('../doc/figures/inb_results_recall_df.pdf',pad_inches=0,bbox_inches='tight')

# %%
inb_results_precision_df = inb_results_df.iloc[:, [2,5]]
ax = inb_results_precision_df.plot(marker='o',ylabel='score',rot=70,figsize=(12,6))
ax.set_xticks(range(len(inb_results_precision_df.index)))
ax.set_xticklabels(inb_results_precision_df.index)
# plt.legend(loc='center left')
fig = ax.get_figure()
fig.savefig('../doc/figures/inb_results_precision_df.pdf',pad_inches=0,bbox_inches='tight')
