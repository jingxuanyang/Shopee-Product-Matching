# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
RESULTS_PATH = '../input/shopee-competition-results/'
test_result_dict = joblib.load(RESULTS_PATH+'test_result_dict.pkl')
image_ensemble_df = pd.read_csv(RESULTS_PATH+'image_ensemble_df.csv')

test_tfidf_result_df = pd.read_csv(RESULTS_PATH+'test_tfidf_result_df.csv')
test_bert_result_dict = joblib.load(RESULTS_PATH+'test_bert_result_dict.pkl')
text_ensemble_df = pd.read_csv(RESULTS_PATH+'text_ensemble_df.csv')

tfidf_resnet_union_df = pd.read_csv(RESULTS_PATH+'tfidf_resnet_union_df.csv')
nfnet_sbert_union_df = pd.read_csv(RESULTS_PATH+'nfnet_sbert_union_df.csv')
tfidf_resnet_ensemble_df = pd.read_csv(RESULTS_PATH+'tfidf_resnet_ensemble_df.csv')
nfnet_sbert_ensemble_df = pd.read_csv(RESULTS_PATH+'nfnet_sbert_ensemble_df.csv')
text_image_union_df = pd.read_csv(RESULTS_PATH+'text_image_union_df.csv')

# %%
min2_results = [[0 for i in range(6)] for j in range(18)]

min2_results[0][0] = round(test_result_dict['resnet50_f1']['arcface'].max(),6)
min2_results[0][1] = round(test_result_dict['resnet50_recall']['arcface'].max(),6)
min2_results[0][2] = round(test_result_dict['resnet50_precision']['arcface'].max(),6)
min2_results[0][3] = round(test_result_dict['resnet50_f1']['arcface_min2'].max(),6)
min2_results[0][4] = round(test_result_dict['resnet50_recall']['arcface_min2'].max(),6)
min2_results[0][5] = round(test_result_dict['resnet50_precision']['arcface_min2'].max(),6)

min2_results[1][0] = round(test_result_dict['resnext50_32x4d_f1']['arcface'].max(),6)
min2_results[1][1] = round(test_result_dict['resnext50_32x4d_recall']['arcface'].max(),6)
min2_results[1][2] = round(test_result_dict['resnext50_32x4d_precision']['arcface'].max(),6)
min2_results[1][3] = round(test_result_dict['resnext50_32x4d_f1']['arcface_min2'].max(),6)
min2_results[1][4] = round(test_result_dict['resnext50_32x4d_recall']['arcface_min2'].max(),6)
min2_results[1][5] = round(test_result_dict['resnext50_32x4d_precision']['arcface_min2'].max(),6)

min2_results[2][0] = round(test_result_dict['densenet121_f1']['arcface'].max(),6)
min2_results[2][1] = round(test_result_dict['densenet121_recall']['arcface'].max(),6)
min2_results[2][2] = round(test_result_dict['densenet121_precision']['arcface'].max(),6)
min2_results[2][3] = round(test_result_dict['densenet121_f1']['arcface_min2'].max(),6)
min2_results[2][4] = round(test_result_dict['densenet121_recall']['arcface_min2'].max(),6)
min2_results[2][5] = round(test_result_dict['densenet121_precision']['arcface_min2'].max(),6)

min2_results[3][0] = round(test_result_dict['efficientnet_b3_f1']['arcface'].max(),6)
min2_results[3][1] = round(test_result_dict['efficientnet_b3_recall']['arcface'].max(),6)
min2_results[3][2] = round(test_result_dict['efficientnet_b3_precision']['arcface'].max(),6)
min2_results[3][3] = round(test_result_dict['efficientnet_b3_f1']['arcface_min2'].max(),6)
min2_results[3][4] = round(test_result_dict['efficientnet_b3_recall']['arcface_min2'].max(),6)
min2_results[3][5] = round(test_result_dict['efficientnet_b3_precision']['arcface_min2'].max(),6)

min2_results[4][0] = round(test_result_dict['eca_nfnet_l0_f1']['arcface'].max(),6)
min2_results[4][1] = round(test_result_dict['eca_nfnet_l0_recall']['arcface'].max(),6)
min2_results[4][2] = round(test_result_dict['eca_nfnet_l0_precision']['arcface'].max(),6)
min2_results[4][3] = round(test_result_dict['eca_nfnet_l0_f1']['arcface_min2'].max(),6)
min2_results[4][4] = round(test_result_dict['eca_nfnet_l0_recall']['arcface_min2'].max(),6)
min2_results[4][5] = round(test_result_dict['eca_nfnet_l0_precision']['arcface_min2'].max(),6)

min2_results[5][0] = round(image_ensemble_df['f1'][0],6)
min2_results[5][1] = round(image_ensemble_df['recall'][0],6)
min2_results[5][2] = round(image_ensemble_df['precision'][0],6)
min2_results[5][3] = round(image_ensemble_df['f1'][1],6)
min2_results[5][4] = round(image_ensemble_df['recall'][1],6)
min2_results[5][5] = round(image_ensemble_df['precision'][1],6)

min2_results[6][0] = round(test_tfidf_result_df['f1'][0],6)
min2_results[6][1] = round(test_tfidf_result_df['recall'][0],6)
min2_results[6][2] = round(test_tfidf_result_df['precision'][0],6)
min2_results[6][3] = round(test_tfidf_result_df['f1'][1],6)
min2_results[6][4] = round(test_tfidf_result_df['recall'][1],6)
min2_results[6][5] = round(test_tfidf_result_df['precision'][1],6)

min2_results[7][0] = round(test_bert_result_dict['bert-base-multilingual-uncased_f1']['arcface'].max(),6)
min2_results[7][1] = round(test_bert_result_dict['bert-base-multilingual-uncased_recall']['arcface'].max(),6)
min2_results[7][2] = round(test_bert_result_dict['bert-base-multilingual-uncased_precision']['arcface'].max(),6)
min2_results[7][3] = round(test_bert_result_dict['bert-base-multilingual-uncased_f1']['arcface_min2'].max(),6)
min2_results[7][4] = round(test_bert_result_dict['bert-base-multilingual-uncased_recall']['arcface_min2'].max(),6)
min2_results[7][5] = round(test_bert_result_dict['bert-base-multilingual-uncased_precision']['arcface_min2'].max(),6)

min2_results[8][0] = round(test_bert_result_dict['bert-base-indonesian-1.5G_f1']['arcface'].max(),6)
min2_results[8][1] = round(test_bert_result_dict['bert-base-indonesian-1.5G_recall']['arcface'].max(),6)
min2_results[8][2] = round(test_bert_result_dict['bert-base-indonesian-1.5G_precision']['arcface'].max(),6)
min2_results[8][3] = round(test_bert_result_dict['bert-base-indonesian-1.5G_f1']['arcface_min2'].max(),6)
min2_results[8][4] = round(test_bert_result_dict['bert-base-indonesian-1.5G_recall']['arcface_min2'].max(),6)
min2_results[8][5] = round(test_bert_result_dict['bert-base-indonesian-1.5G_precision']['arcface_min2'].max(),6)

min2_results[9][0] = round(test_bert_result_dict['distilbert-base-indonesian_f1']['arcface'].max(),6)
min2_results[9][1] = round(test_bert_result_dict['distilbert-base-indonesian_recall']['arcface'].max(),6)
min2_results[9][2] = round(test_bert_result_dict['distilbert-base-indonesian_precision']['arcface'].max(),6)
min2_results[9][3] = round(test_bert_result_dict['distilbert-base-indonesian_f1']['arcface_min2'].max(),6)
min2_results[9][4] = round(test_bert_result_dict['distilbert-base-indonesian_recall']['arcface_min2'].max(),6)
min2_results[9][5] = round(test_bert_result_dict['distilbert-base-indonesian_precision']['arcface_min2'].max(),6)

min2_results[10][0] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_f1']['arcface'].max(),6)
min2_results[10][1] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_recall']['arcface'].max(),6)
min2_results[10][2] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_precision']['arcface'].max(),6)
min2_results[10][3] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_f1']['arcface_min2'].max(),6)
min2_results[10][4] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_recall']['arcface_min2'].max(),6)
min2_results[10][5] = round(test_bert_result_dict['paraphrase-xlm-r-multilingual-v1_precision']['arcface_min2'].max(),6)

min2_results[11][0] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_f1']['arcface'].max(),6)
min2_results[11][1] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_recall']['arcface'].max(),6)
min2_results[11][2] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_precision']['arcface'].max(),6)
min2_results[11][3] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_f1']['arcface_min2'].max(),6)
min2_results[11][4] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_recall']['arcface_min2'].max(),6)
min2_results[11][5] = round(test_bert_result_dict['paraphrase-distilroberta-base-v1_precision']['arcface_min2'].max(),6)

min2_results[12][0] = round(text_ensemble_df['f1'][0],6)
min2_results[12][1] = round(text_ensemble_df['recall'][0],6)
min2_results[12][2] = round(text_ensemble_df['precision'][0],6)
min2_results[12][3] = round(text_ensemble_df['f1'][1],6)
min2_results[12][4] = round(text_ensemble_df['recall'][1],6)
min2_results[12][5] = round(text_ensemble_df['precision'][1],6)

min2_results[13][0] = round(tfidf_resnet_union_df['f1'][0],6)
min2_results[13][1] = round(tfidf_resnet_union_df['recall'][0],6)
min2_results[13][2] = round(tfidf_resnet_union_df['precision'][0],6)
min2_results[13][3] = round(tfidf_resnet_union_df['f1'][1],6)
min2_results[13][4] = round(tfidf_resnet_union_df['recall'][1],6)
min2_results[13][5] = round(tfidf_resnet_union_df['precision'][1],6)

min2_results[14][0] = round(nfnet_sbert_union_df['f1'][0],6)
min2_results[14][1] = round(nfnet_sbert_union_df['recall'][0],6)
min2_results[14][2] = round(nfnet_sbert_union_df['precision'][0],6)
min2_results[14][3] = round(nfnet_sbert_union_df['f1'][1],6)
min2_results[14][4] = round(nfnet_sbert_union_df['recall'][1],6)
min2_results[14][5] = round(nfnet_sbert_union_df['precision'][1],6)

min2_results[15][0] = round(tfidf_resnet_ensemble_df['f1'][0],6)
min2_results[15][1] = round(tfidf_resnet_ensemble_df['recall'][0],6)
min2_results[15][2] = round(tfidf_resnet_ensemble_df['precision'][0],6)
min2_results[15][3] = round(tfidf_resnet_ensemble_df['f1'][1],6)
min2_results[15][4] = round(tfidf_resnet_ensemble_df['recall'][1],6)
min2_results[15][5] = round(tfidf_resnet_ensemble_df['precision'][1],6)

min2_results[16][0] = round(nfnet_sbert_ensemble_df['f1'][0],6)
min2_results[16][1] = round(nfnet_sbert_ensemble_df['recall'][0],6)
min2_results[16][2] = round(nfnet_sbert_ensemble_df['precision'][0],6)
min2_results[16][3] = round(nfnet_sbert_ensemble_df['f1'][1],6)
min2_results[16][4] = round(nfnet_sbert_ensemble_df['recall'][1],6)
min2_results[16][5] = round(nfnet_sbert_ensemble_df['precision'][1],6)

min2_results[17][0] = round(text_image_union_df['f1'][0],6)
min2_results[17][1] = round(text_image_union_df['recall'][0],6)
min2_results[17][2] = round(text_image_union_df['precision'][0],6)
min2_results[17][3] = round(text_image_union_df['f1'][1],6)
min2_results[17][4] = round(text_image_union_df['recall'][1],6)
min2_results[17][5] = round(text_image_union_df['precision'][1],6)

# %%
min2_results_df = pd.DataFrame(min2_results,columns=['f1','recall','precision','f1_min2','recall_min2','precision_min2'],index=['resnet50','resnext50_32x4d','densenet121','efficientnet_b3','eca_nfnet_l0','image ensemble','tf-idf','bert-base-multilingual-uncased','bert-base-indonesian-1.5G','distilbert-base-indonesian','paraphrase-xlm-r-multilingual-v1','paraphrase-distilroberta-base-v1','text ensemble','tfidf resnet union','nfnet sbert union','tfidf resnet ensemble','nfnet sbert ensemble','text image union'])
min2_results_df
# Out:
#                                         f1    recall  precision   f1_min2  \
# resnet50                          0.757385  0.726135   0.925569  0.762153
# resnext50_32x4d                   0.760473  0.731729   0.928756  0.768830
# densenet121                       0.762457  0.739039   0.928803  0.766886
# efficientnet_b3                   0.774103  0.764059   0.912719  0.780399
# eca_nfnet_l0                      0.788663  0.771427   0.911394  0.798483
# image ensemble                    0.789446  0.781857   0.901332  0.798919
# tf-idf                            0.783220  0.794429   0.863616  0.789865
# bert-base-multilingual-uncased    0.817695  0.848685   0.884845  0.825374
# bert-base-indonesian-1.5G         0.812737  0.843387   0.868974  0.820426
# distilbert-base-indonesian        0.808627  0.845347   0.861303  0.813436
# paraphrase-xlm-r-multilingual-v1  0.821114  0.848321   0.882831  0.829395
# paraphrase-distilroberta-base-v1  0.802462  0.834882   0.872976  0.808062
# ...

# %%
min2_results_df.to_csv('min2_results_df.csv')

# %%
ax = min2_results_df.plot(marker='o',ylabel='score',rot=70,figsize=(12,8))
ax.set_xticks(range(len(min2_results_df.index)))
ax.set_xticklabels(min2_results_df.index)
# plt.legend(loc='center left')
fig = ax.get_figure()
# fig.savefig('../doc/figures/min2_results_df.pdf',pad_inches=0,bbox_inches='tight')

# %%
min2_results_f1_df = min2_results_df.iloc[:, [0,3]]
min2_results_f1_df
# Out:
#                                         f1   f1_min2
# resnet50                          0.757385  0.762153
# resnext50_32x4d                   0.760473  0.768830
# densenet121                       0.762457  0.766886
# efficientnet_b3                   0.774103  0.780399
# eca_nfnet_l0                      0.788663  0.798483
# image ensemble                    0.789446  0.798919
# tf-idf                            0.783220  0.789865
# bert-base-multilingual-uncased    0.817695  0.825374
# bert-base-indonesian-1.5G         0.812737  0.820426
# distilbert-base-indonesian        0.808627  0.813436
# paraphrase-xlm-r-multilingual-v1  0.821114  0.829395
# paraphrase-distilroberta-base-v1  0.802462  0.808062
# text ensemble                     0.828340  0.834841
# tfidf resnet union                0.833676  0.833025
# nfnet sbert union                 0.852916  0.848255
# tfidf resnet ensemble             0.869537  0.878699
# nfnet sbert ensemble              0.880711  0.888967
# ...

# %%
min2_results_f1_df = min2_results_df.iloc[:, [0,3]]
ax = min2_results_f1_df.plot(marker='o',ylabel='score',rot=70,figsize=(12,6))
ax.set_xticks(range(len(min2_results_f1_df.index)))
ax.set_xticklabels(min2_results_f1_df.index)
# plt.legend(loc='center left')
fig = ax.get_figure()
fig.savefig('../doc/figures/min2_results_f1_df.pdf',pad_inches=0,bbox_inches='tight')

# %%
min2_results_recall_df = min2_results_df.iloc[:, [1,4]]
ax = min2_results_recall_df.plot(marker='o',ylabel='score',rot=70,figsize=(12,6))
ax.set_xticks(range(len(min2_results_recall_df.index)))
ax.set_xticklabels(min2_results_recall_df.index)
# plt.legend(loc='center left')
fig = ax.get_figure()
fig.savefig('../doc/figures/min2_results_recall_df.pdf',pad_inches=0,bbox_inches='tight')

# %%
min2_results_precision_df = min2_results_df.iloc[:, [2,5]]
ax = min2_results_precision_df.plot(marker='o',ylabel='score',rot=70,figsize=(12,6))
ax.set_xticks(range(len(min2_results_precision_df.index)))
ax.set_xticklabels(min2_results_precision_df.index)
# plt.legend(loc='center left')
fig = ax.get_figure()
fig.savefig('../doc/figures/min2_results_precision_df.pdf',pad_inches=0,bbox_inches='tight')
